# %% [markdown]
# ### 특정 상품 주문시 함께 가장 많이 주문된 다른 상품 추출하기

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from sqlalchemy import create_engine

# %%
conn_string = 'postgresql://postgres:postgres@localhost:5432/online_sales'
postgres_engine = create_engine(conn_string)

# %%
query = """
select a.description as product_1, b.description as product_2,
       count(*) as combi_count
from os.sales a 
	join os.sales b on a.invoice_num = b.invoice_num
where a.description != b.description
group by 1,2
"""

df = pd.read_sql_query(sql=query, con=postgres_engine)
df
# Out:
#                                 product_1  \
# 0           4 PURPLE FLOCK DINNER CANDLES
# 1           4 PURPLE FLOCK DINNER CANDLES
# 2           4 PURPLE FLOCK DINNER CANDLES
# 3           4 PURPLE FLOCK DINNER CANDLES
# 4           4 PURPLE FLOCK DINNER CANDLES
# ...                                   ...
# 4553985  ZINC WIRE SWEETHEART LETTER TRAY
# 4553986  ZINC WIRE SWEETHEART LETTER TRAY
# 4553987  ZINC WIRE SWEETHEART LETTER TRAY
# 4553988  ZINC WIRE SWEETHEART LETTER TRAY
# 4553989  ZINC WIRE SWEETHEART LETTER TRAY
#
#                                    product_2  combi_count
# 0                     10 COLOUR SPACEBOY PEN            3
# 1           12 IVORY ROSE PEG PLACE SETTINGS            1
# 2              12 PENCIL SMALL TUBE WOODLAND            3
# 3        12 PENCILS SMALL TUBE RED RETROSPOT            3
# 4                12 PENCILS SMALL TUBE SKULL            1
# ...                                      ...          ...
# 4553985     ZINC SWEETHEART WIRE LETTER RACK            2
# 4553986       ZINC T-LIGHT HOLDER STAR LARGE            1
# 4553987      ZINC T-LIGHT HOLDER STARS SMALL            2
# 4553988     ZINC WILLIE WINKIE  CANDLE STICK            1
# 4553989          ZINC WIRE KITCHEN ORGANISER            1
#
# [4553990 rows x 3 columns]

# %%
query = """
with 
tmp_01 as (
    select a.description as product_1, b.description as product_2,
           count(*) as combi_count
    from os.sales a 
        join os.sales b on a.invoice_num = b.invoice_num
    where a.description != b.description
    group by 1,2
),
tmp_02 as (
    select product_1, product_2, combi_count,
           rank() over (partition by product_1 order by combi_count desc) as ranking
    from tmp_01
)
select *
from tmp_02
where ranking = 1
"""

df = pd.read_sql_query(sql=query, con=postgres_engine)
df
# Out:
#                               product_1                          product_2  \
# 0         4 PURPLE FLOCK DINNER CANDLES  4 PINK DINNER CANDLE SILVER FLOCK
# 1         50'S CHRISTMAS GIFT BAG LARGE      50'S CHRISTMAS PAPER GIFT BAG
# 2                     DOLLY GIRL BEAKER                    SPACEBOY BEAKER
# 3           I LOVE LONDON MINI BACKPACK             SPACEBOY MINI BACKPACK
# 4           I LOVE LONDON MINI RUCKSACK             SPACEBOY MINI RUCKSACK
# ...                                 ...                                ...
# 12080       ZINC WIRE KITCHEN ORGANISER          ZINC SWEETHEART SOAP DISH
# 12081       ZINC WIRE KITCHEN ORGANISER      SET OF 3 CAKE TINS SKETCHBOOK
# 12082       ZINC WIRE KITCHEN ORGANISER        WOODEN FRAME ANTIQUE WHITE
# 12083       ZINC WIRE KITCHEN ORGANISER     FRENCH KITCHEN SIGN BLUE METAL
# 12084  ZINC WIRE SWEETHEART LETTER TRAY  IVORY WIRE SWEETHEART LETTER TRAY
#
#        combi_count  ranking
# 0               18        1
# 1               66        1
# 2              108        1
# 3               40        1
# 4                1        1
# ...            ...      ...
# 12080            5        1
# 12081            5        1
# 12082            5        1
# 12083            5        1
# 12084            6        1
#
# [12085 rows x 4 columns]
